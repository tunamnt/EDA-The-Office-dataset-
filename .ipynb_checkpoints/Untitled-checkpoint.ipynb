# %% [markdown]
# The Office! What started as a British mockumentary series about office culture in 2001 has since spawned ten other variants across the world, including an Israeli version (2010-13), a Hindi version (2019-), and even a French Canadian variant (2006-2007). Of all these iterations (including the original), the American series has been the longest-running, spanning 201 episodes over nine seasons.
#
#
# In this notebook, we will take a look at a dataset of The Office episodes, and try to understand how the popularity and quality of the series varied over time.

# %% [markdown]
# - episode_number: Canonical episode number.
# - season: Season in which the episode appeared.
# - episode_title: Title of the episode.
# - description: Description of the episode.
# - ratings: Average IMDB rating.
# - votes: Number of votes.
# - viewership_mil: Number of US viewers in millions.
# - duration: Duration in number of minutes.
# - release_date: Airdate.
# - guest_stars: Guest stars in the episode (if any).
# - director: Director of the episode.
# - writers: Writers of the episode.
# - has_guests: True/False column for whether the episode contained guest stars.
# - scaled_ratings: The ratings scaled from 0 (worst-reviewed) to 1 (best-reviewed).m

# %%
# import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme()

# %%
# read data
data = pd.read_csv('office_episodes.csv')
data.head()
# Out:
#    episode_number  season  episode_title  \
# 0               0       1          Pilot
# 1               1       1  Diversity Day
# 2               2       1    Health Care
# 3               3       1   The Alliance
# 4               4       1     Basketball
#
#                                          description  ratings  votes  \
# 0  The premiere episode introduces the boss and s...      7.5   4936
# 1  Michael's off color remark puts a sensitivity ...      8.3   4801
# 2  Michael leaves Dwight in charge of picking the...      7.8   4024
# 3  Just for a laugh, Jim agrees to an alliance wi...      8.1   3915
# 4  Michael and his staff challenge the warehouse ...      8.4   4294
#
#    viewership_mil  duration release_date guest_stars         director  \
# 0            11.2        23   2005-03-24         NaN       Ken Kwapis
# 1             6.0        23   2005-03-29         NaN       Ken Kwapis
# 2             5.8        22   2005-04-05         NaN  Ken Whittingham
# 3             5.4        23   2005-04-12         NaN     Bryan Gordon
# 4             5.0        23   2005-04-19         NaN     Greg Daniels
#
#                                             writers  has_guests  \
# 0  Ricky Gervais |Stephen Merchant and Greg Daniels       False
# 1                                       B. J. Novak       False
# 2                                  Paul Lieberstein       False
# 3                                     Michael Schur       False
# 4                                      Greg Daniels       False
#
#    scaled_ratings
# 0         0.28125
# 1         0.53125
# 2         0.37500
# 3         0.46875
# 4         0.56250

# %%
# data describe
data.describe()
# Out:
#        episode_number      season     ratings         votes  viewership_mil  \
# count      188.000000  188.000000  188.000000    188.000000      188.000000
# mean        93.500000    5.468085    8.237234   2838.228723        7.246330
# std         54.415071    2.386245    0.589930   1063.165290        2.066012
# min          0.000000    1.000000    6.600000   1832.000000        3.250000
# 25%         46.750000    3.000000    7.800000   2187.750000        5.990000
# 50%         93.500000    6.000000    8.200000   2614.000000        7.535000
# 75%        140.250000    7.250000    8.600000   3144.250000        8.425000
# max        187.000000    9.000000    9.800000  10515.000000       22.910000
#
#          duration  scaled_ratings
# count  188.000000      188.000000
# mean    27.053191        0.511636
# std      6.937254        0.184353
# min     19.000000        0.000000
# 25%     22.000000        0.375000
# 50%     23.000000        0.500000
# 75%     30.000000        0.625000
# max     60.000000        1.000000

# %%
# data info
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 188 entries, 0 to 187
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   episode_number  188 non-null    int64
#  1   season          188 non-null    int64
#  2   episode_title   188 non-null    object
#  3   description     188 non-null    object
#  4   ratings         188 non-null    float64
#  5   votes           188 non-null    int64
#  6   viewership_mil  188 non-null    float64
#  7   duration        188 non-null    int64
#  8   release_date    188 non-null    object
#  9   guest_stars     29 non-null     object
#  10  director        188 non-null    object
#  11  writers         188 non-null    object
#  12  has_guests      188 non-null    bool
#  13  scaled_ratings  188 non-null    float64
# dtypes: bool(1), float64(3), int64(4), object(6)
# memory usage: 19.4+ KB

# %%
# discover guest_stars column
data['guest_stars'].unique()
# Out:
# array([nan, 'Amy Adams', 'Nancy Carell', 'Tim Meadows', 'Ken Jeong',
#        'Rob Riggle', "Conan O'Brien", 'Jerome Bettis', 'Kevin McHale',
#        'Wendi McLendon-Covey',
#        'Cloris Leachman, Jack Black, Jessica Alba', 'Idris Elba',
#        'Mike Starr', 'Christian Slater', 'Mellisa Rauch', 'Evan Peters',
#        'Timothy Olyphant', 'Ricky Gervais',
#        'Will Arnett,  Ray Romano, Jim Carrey, Ricky Gervais',
#        'Will Ferrell', 'Josh Groban, Stephen Collins', 'Maura Tierney',
#        'Chris Bauer', 'Stephen Colbert', 'Josh Groban',
#        'Julius Winfield Erving', 'Ryan Howard', 'Michael Imperioli ',
#        'Joan Cusack, Ed Begley Jr, Rachel Harris, Nancy Walls'],
#       dtype=object)

# %%
# type of release_date
type(data['release_date'])
# Out:
# pandas.core.series.Series

# %%
# create year column
data['release_date'] = pd.to_datetime(data['release_date'])
data['year'] = data['release_date'].dt.year

# %%
# season vs ratings
data['ratings'].groupby(data['season']).mean()
# Out:
# season
# 1    7.966667
# 2    8.440909
# 3    8.586957
# 4    8.564286
# 5    8.488462
# 6    8.196154
# 7    8.308333
# 8    7.604167
# 9    7.913043
# Name: ratings, dtype: float64

# %%
# season vs scale_rating
data['scaled_ratings'].groupby(data['season']).mean()
# Out:
# season
# 1    0.427083
# 2    0.575284
# 3    0.620924
# 4    0.613839
# 5    0.590144
# 6    0.498798
# 7    0.533854
# 8    0.313802
# 9    0.410326
# Name: scaled_ratings, dtype: float64

# %%
# director vs ratings
a1 = pd.DataFrame(data['ratings'].groupby(data['director']).agg( 'mean')).sort_values(by="ratings", ascending=False)
# director vs count
a2 = pd.DataFrame(data['episode_number'].groupby(data['director']).agg('count'))
pd.merge(a1,a2, on='director')
# Out:
#                         ratings  episode_number
# director
# Harold Ramis           8.825000               4
# Jason Reitman          8.800000               1
# Steve Carell           8.766667               3
# Paul Feig              8.753333              15
# Joss Whedon            8.700000               2
# Gene Stupnitsky        8.700000               1
# Tucker Gates           8.650000               4
# Ken Kwapis             8.607692              13
# Julian Farino          8.600000               2
# Lee Eisenberg          8.600000               1
# Bryan Gordon           8.600000               2
# Mindy Kaling           8.500000               2
# Stephen Merchant       8.500000               1
# J.J. Abrams            8.500000               1
# Dean Holland           8.450000               2
# Greg Daniels           8.446154              13
# Charles McDougall      8.375000               8
# Jeffrey Blitz          8.309091              11
# Craig Zisk             8.300000               1
# Dennie Gordon          8.300000               1
# Ken Whittingham        8.262500               8
# Seth Gordon            8.250000               2
# Reginald Hudlin        8.200000               1
# John Scott             8.200000               1
# See full summary       8.185714               7
# Paul Lieberstein       8.142857               7
# Randall Einhorn        8.113333              15
# Brian Baumgartner      8.100000               1
# Jon Favreau            8.100000               1
# Marc Webb              8.100000               1
# Jennifer Celotta       8.033333               3
# Asaad Kelada           8.000000               1
# Roger Nygard           8.000000               1
# Jesse Peretz           8.000000               1
# B.J. Novak             7.920000               5
# David Rogers           7.911111               9
# Rainn Wilson           7.900000               3
# Kelly Cantley-Kashima  7.900000               1
# Miguel Arteta          7.900000               1
# Brent Forrester        7.900000               4
# Troy Miller            7.900000               3
# Victor Nelli Jr.       7.800000               1
# Matt Sohn              7.800000               8
# Bryan Cranston         7.800000               1
# Amy Heckerling         7.700000               1
# Charlie Grandy         7.700000               1
# Rodman Flender         7.600000               1
# Daniel Chun            7.600000               1
# John Krasinski         7.566667               3
# Lee Kirk               7.500000               1
# Ed Helms               7.500000               2
# Eric Appel             7.400000               1
# Alex Hardcastle        7.400000               1
# Claire Scanlon         7.000000               2

# %%
# ratings vs has_guests
data['ratings'].groupby(data['has_guests']).mean()
# Out:
# has_guests
# False    8.244654
# True     8.196552
# Name: ratings, dtype: float64

# %%
# ratings vs votes
plt.scatter(x = data['votes'], y = data['ratings'], )
plt.title('number of votes and ratings')
plt.xlabel('votes')
plt.ylabel('ratings')
plt.show()

# %%
# ratings vs viewership_mil
plt.scatter(x = data['viewership_mil'], y = data['ratings'], c = data['votes'])
plt.title('number of votes and ratings')
plt.xlabel('viewership_mil')
plt.ylabel('ratings')
#plt.legend(data['votes'])
plt.show()

# %%
# ratings over year
plt.scatter(x = data['year'], y = data['ratings'])
plt.title('number of votes and ratings')
plt.xlabel('year')
plt.ylabel('ratings')
plt.show()

# %%
plt.figure(figsize=(10,10))
sns.heatmap(data.corr(),annot=True)
plt.show()

# %%
# color column for viewership
cols = []

for ind, row in data.iterrows():
    if row['scaled_ratings'] < 0.25:
        cols.append('red')
    elif row['scaled_ratings'] < 0.5:
        cols.append('orange')
    elif row['scaled_ratings'] < 0.75:
        cols.append('lightgreen')
    else:
        cols.append('darkgreen')

# %%
# viewership column
sizes = []

for ind, row in data.iterrows():
    if row['has_guests'] == False:
        sizes.append(25)
    else:
        sizes.append(250)

# %%
# create columns of color and size:
data['cols'] = cols
data['sizes'] = sizes

# %%
# data with guest stars vs data without guest stars
data_w_guests = data[data['has_guests'] == True]
data_wo_guests = data[data['has_guests']==False]

# %%
# viewership vs episode
plt.figure(figsize=(15,10))
plt.scatter(x=data_wo_guests['episode_number'], y=data_wo_guests['viewership_mil'], c= data_wo_guests['cols'], 
            s=data_wo_guests['sizes'])
plt.scatter(x=data_w_guests['episode_number'], y=data_w_guests['viewership_mil'], c= data_w_guests['cols'], 
            s=data_w_guests['sizes'], marker='*')
plt.xlabel('episode number')
plt.ylabel('viewership')
plt.title('viewership trend over episode')
plt.show()

# %%
# Provide the name of one of the guest stars who was in the most watched Office episode. 
top_star = data[data['viewership_mil'] == data['viewership_mil'].max()]
top_star['guest_stars']
# Out:
# 77    Cloris Leachman, Jack Black, Jessica Alba
# Name: guest_stars, dtype: object

# %%
# most popular guest stars using groupby
top_stars = pd.DataFrame(data['viewership_mil'].groupby(data['guest_stars']).mean()).sort_values(by = 'viewership_mil', 
                                                                                                 ascending=False)
top_stars.head(1)
# Out:
#                                            viewership_mil
# guest_stars
# Cloris Leachman, Jack Black, Jessica Alba           22.91
